# %%
# !pip install yfinance
# !pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\star_\appdata\roaming\python\python39\site-packages (0.1.87)
# Requirement already satisfied: appdirs>=1.4.4 in n:\program\python\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\star_\appdata\roaming\python\python39\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pandas>=0.24.0 in n:\program\python\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.26 in n:\program\python\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: lxml>=4.5.1 in n:\program\python\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: numpy>=1.15 in n:\program\python\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in n:\program\python\lib\site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in n:\program\python\lib\site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in n:\program\python\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in n:\program\python\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in n:\program\python\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in n:\program\python\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: six>=1.5 in n:\program\python\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import time
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
ticker = yf.Ticker("YNDX")
start = datetime.datetime(2012,1,1)
end =datetime.datetime(2020,1,11)
data = ticker.history(start = start, end = end, interval = "1d")

# Sort the dataframe according to the date
data.sort_values('Date', inplace=True, ascending=True)

# Print the dataframe top
data.head()

# Visualization of data. Plotting the price close.
plt.figure(num=None, figsize=(15, 6), dpi=80, facecolor='w', edgecolor='k')
data['Close'].plot()
plt.tight_layout()
plt.grid()
plt.show()

# %%
# Get Close data
df = data[['Close']].copy()
# Split data into train and test
train, test = df.iloc[0:-200], df.iloc[-200:len(df)]
print(len(train), len(test))
# Out:
# 1819 200

# %%
train_max = train.max()
train_min = train.min()

# Normalize the dataframes
train = (train - train_min)/(train_max - train_min)
test = (test - train_min)/(train_max - train_min)

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)


time_steps = 10

X_train, y_train = create_dataset(train, train.Close, time_steps)
X_test, y_test = create_dataset(test, test.Close, time_steps)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential()
model.add(keras.layers.LSTM(250, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(1))
model.compile(loss='mae', optimizer='adam')
model.summary()

history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    shuffle=False
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 250)               252000
#
#  dropout (Dropout)           (None, 250)               0
#
#  dense (Dense)               (None, 1)                 251
#
# =================================================================
# Total params: 252,251
# Trainable params: 252,251
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 2s 15ms/step - loss: 0.0680
# Epoch 2/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0707
# Epoch 3/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.1120
# Epoch 4/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.1142
# Epoch 5/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0997
# Epoch 6/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0801
# Epoch 7/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0703
# Epoch 8/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0642
# Epoch 9/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0607
# Epoch 10/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0577
# Epoch 11/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0511
# Epoch 12/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0544
# Epoch 13/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0497
# Epoch 14/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0519
# Epoch 15/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0471
# Epoch 16/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0441
# Epoch 17/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0430
# Epoch 18/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0448
# Epoch 19/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0393
# Epoch 20/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0385
# Epoch 21/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0396
# Epoch 22/50
# 57/57 [==============================] - 1s 14ms/step - loss: 0.0434
# Epoch 23/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0373
# Epoch 24/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0386
# Epoch 25/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0357
# Epoch 26/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0355
# Epoch 27/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0355
# Epoch 28/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0324
# Epoch 29/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0352
# Epoch 30/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0325
# Epoch 31/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0334
# Epoch 32/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0347
# Epoch 33/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0327
# Epoch 34/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0318
# Epoch 35/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0325
# Epoch 36/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0324
# Epoch 37/50
# 57/57 [==============================] - 1s 17ms/step - loss: 0.0294
# Epoch 38/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0341
# Epoch 39/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0291
# Epoch 40/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0309
# Epoch 41/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0298
# Epoch 42/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0290
# Epoch 43/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0309
# Epoch 44/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0274
# Epoch 45/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0298
# Epoch 46/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0281
# Epoch 47/50
# 57/57 [==============================] - 1s 15ms/step - loss: 0.0293
# Epoch 48/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0273
# Epoch 49/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0294
# Epoch 50/50
# 57/57 [==============================] - 1s 16ms/step - loss: 0.0277

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in c:\users\star_\appdata\roaming\python\python39\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (63.4.1)
# Requirement already satisfied: h5py>=2.9.0 in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy>=1.20 in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.5)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.27.0)
# Requirement already satisfied: packaging in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (21.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (14.0.6)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.10.26)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in n:\program\python\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.50.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in n:\program\python\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\star_\appdata\roaming\python\python39\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in n:\program\python\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.3)
# Requirement already satisfied: markdown>=2.6.8 in n:\program\python\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in n:\program\python\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in n:\program\python\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\star_\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in n:\program\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in n:\program\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in n:\program\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in n:\program\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in n:\program\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in n:\program\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\star_\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
plt.plot(history.history['loss'], label='train')
plt.legend();
plt.show()

# %%
plt.rcParams ['figure.figsize'] = [20, 8]

# %%
y_pred = model.predict(X_test)

# Rescale the data back to the original scale
y_test = y_test*(train_max[0] - train_min[0]) + train_min[0]
y_pred = y_pred*(train_max[0] - train_min[0]) + train_min[0]
y_train = y_train*(train_max[0] - train_min[0]) + train_min[0]

# Plotting the results
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test.flatten(), label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred.flatten(), label="prediction")
plt.plot(np.arange(0, len(y_train)), y_train.flatten(), label="history")
plt.ylabel('Close')
plt.xlabel('Time Step')
plt.legend()
plt.show()
# Out:
# 6/6 [==============================] - 0s 7ms/step
